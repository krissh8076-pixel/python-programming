# %% [markdown]
# # Section - A

# %% [markdown]
# # Q-1

# %%
class Student:
    school_name ="UPES" 
    
    def __init__ (self, name, age):
        self.name = name
        self.age = age 
        
s1 = Student("Aman", 20)
s2 = Student("riya", 21)

print("school:",s1.school_name)
print("Student 1: ", s1.name,s1.age)
print("Student 2: ", s2.name,s2.age)
# Out:
# school: UPES
# Student 1:  Aman 20
# Student 2:  riya 21

# %% [markdown]
# # Q2. Instance Method and Class Method

# %%
class Employee:
    company = "ABC Ltd"  

    def __init__(self, name, salary):
        self.name = name          
        self.salary = salary     
    def show_details(self):
        print(f"Name: {self.name}, Salary: {self.salary}, Company: {Employee.company}")
    @classmethod
    def change_company(cls, new_name):
        cls.company = new_name
emp1 = Employee("Ravi", 50000)
emp= Employee("Priya", 60000)
print("Before company name change:")
emp1.show_details()
emp2.show_details()
Employee.change_company("XYZ Pvt Ltd")
print("\nAfter company name change:")
emp1.show_details()
emp2.show_details()
# Out:
# Before company name change:
# Name: Ravi, Salary: 50000, Company: ABC Ltd
# name:Sita, salary: 60000,company:ABC Ltd
#
# After company name change:
# Name: Ravi, Salary: 50000, Company: XYZ Pvt Ltd
# name:Sita, salary: 60000,company:XYZ Pvt Ltd

# %% [markdown]
# # Q3

# %%
class MathHelper:
    @staticmethod
    def is_even(num):
        return num % 2 == 0


print(MathHelper.is_even(8))  
print(MathHelper.is_even(11))
# Out:
# True
# False

# %% [markdown]
# # Section -c

# %% [markdown]
# # Q6. Magic Methods / Operator Overloading

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price
    def __str__(self):
        return f"Product: {self.name}, Price: {self.price}"
    def __add__(self, other):
        return self.price + other.price
    def __eq__(self, other):
        return self.price == other.price

p1 = Product("Laptop", 50000)
p2 = Product("Phone", 30000)
p3 = Product("Tablet", 50000)
print(p1)          
print(p1 + p2)     
print(p1 == p3)    
print(p1 == p2)
# Out:
# Product: Laptop, Price: 50000
# 80000
# True
# False

# %% [markdown]
# # sectipon B

# %% [markdown]
# # Q5

# %%
class Student:
    def __init__(self, name, roll_no):
        self.name = name
        self.roll_no = roll_no

print(Student.__name__)    
print(Student.__doc__)     
print(Student.__module__)  
print(Student.__dict__)
# Out:
# Student
# None
# __main__
# {'__module__': '__main__', '__firstlineno__': 1, '__init__': <function Student.__init__ at 0x14ec34f40>, '__static_attributes__': ('name', 'roll_no'), '__dict__': <attribute '__dict__' of 'Student' objects>, '__weakref__': <attribute '__weakref__' of 'Student' objects>, '__doc__': None}
